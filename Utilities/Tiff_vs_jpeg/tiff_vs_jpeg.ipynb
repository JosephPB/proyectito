# %%
import numpy as np
import matplotlib.pyplot as plt
import rasterio
import cv2

# %%
tiff_file = rasterio.open("wrist_nc.tif")
tiff_image = tiff_file.read(1)
jpeg_image = cv2.imread("Wrist_nc.jpg")
label_image = cv2.imread("Wrist_label.jpg")
# Out:
# c:\users\arnau.quera-bofarull\appdata\local\programs\python\python36\lib\site-packages\rasterio\__init__.py:249: NotGeoreferencedWarning: Dataset has no geotransform set. Default transform will be applied (Affine.identity())
#   s = DatasetReader(fp, driver=driver, **kwargs)

# %%
plt.imshow(tiff_image, cmap = 'gray')
plt.show()

# %%
plt.imshow(jpeg_image)

# %%
plt.imshow(label_image)

# %%
print(jpeg_image.shape)
print(tiff_image.shape)
print(label_image.shape)
# Out:
# (1356, 1365, 3)
# (1356, 1365)
# (1335, 1350, 3)

# %%
#resize
jpeg_resized = cv2.resize(jpeg_image, (200,200))
tiff_resized = cv2.resize(tiff_image, (200,200))
label_resized = cv2.resize(label_)

# %%
print("jpeg")
plt.imshow(jpeg_resized, cmap = 'gray')
plt.imshow(label_image, alpha=0.2)
plt.show()
print("tiff")
plt.imshow(tiff_resized, cmap = 'gray')
plt.show()
# Out:
# jpeg
# tiff

# %%
# Out:
# array([[ 4375.7417,  4146.0444,  4018.76  , ..., 10094.71  ,  9949.912 ,
#          9896.895 ],
#        [ 4817.722 ,  4722.818 ,  4413.7036, ..., 10037.866 ,  9950.797 ,
#          9938.695 ],
#        [ 5004.9434,  4990.9043,  4655.9814, ..., 10082.459 ,  9966.952 ,
#          9893.958 ],
#        ...,
#        [ 7908.5605,  9021.096 ,  9926.959 , ...,  8542.981 ,  8759.503 ,
#          8773.012 ],
#        [ 7900.642 ,  9045.486 ,  9937.555 , ...,  7920.4077,  8041.6265,
#          8146.601 ],
#        [ 7877.7593,  8973.475 ,  9876.821 , ...,  6659.38  ,  6668.4165,
#          6791.783 ]], dtype=float32)
